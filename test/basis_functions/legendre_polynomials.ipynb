# %% [markdown]
# # Test Legendre Polynomials

# %%
using GeometricIntegrators

# %%
using Gadfly

# %% [markdown]
# Number of basis functions to plot:

# %%
s = 5
# Out:
# 5

# %% [markdown]
# Number of points to plot:

# %%
np = 101
# Out:
# 101

# %% [markdown]
# Define Lagrange polynomial:

# %%
leg = LegendreBasis(Float64, s)
# Out:
# GeometricIntegrators.BasisFunctions.LegendreBasis{Float64,5,Tuple{Int64,Float64,Float64,Float64,Int64,Float64},NTuple{6,Polynomials.Poly{Int64}},NTuple{6,Polynomials.Poly{Int64}},NTuple{6,Polynomials.Poly{Float64}}}((1, 1.7320508075688772, 2.23606797749979, 2.6457513110645907, 3, 3.3166247903554), (Poly(1), Poly(-1 + 2*x), Poly(1 - 6*x + 6*x^2), Poly(-1 + 12*x - 30*x^2 + 20*x^3), Poly(1 - 20*x + 90*x^2 - 140*x^3 + 70*x^4), Poly(-1 + 30*x - 210*x^2 + 560*x^3 - 630*x^4 + 252*x^5)), (Poly(0), Poly(2), Poly(-6 + 12*x), Poly(12 - 60*x + 60*x^2), Poly(-20 + 180*x - 420*x^2 + 280*x^3), Poly(30 - 420*x + 1680*x^2 - 2520*x^3 + 1260*x^4)), (Poly(1.0*x), Poly(-1.0*x + 1.0*x^2), Poly(1.0*x - 3.0*x^2 + 2.0*x^3), Poly(-1.0*x + 6.0*x^2 - 10.0*x^3 + 5.0*x^4), Poly(1.0*x - 10.0*x^2 + 30.0*x^3 - 35.0*x^4 + 14.0*x^5), Poly(-1.0*x + 15.0*x^2 - 70.0*x^3 + 140.0*x^4 - 126.0*x^5 + 42.0*x^6)))

# %% [markdown]
# Compute plot range:

# %%
xp = collect(linspace(0, 1, np));

# %% [markdown]
# Plot all basis polynomials:

# %%
layers = []

for i in 1:nbasis(leg)
    yp = zeros(xp)
    for j in eachindex(xp,yp)
        yp[j] = evaluate(leg, i, xp[j])
    end
    push!(layers, layer(x=xp, y=yp, Geom.line))
end

plot(layers...)
# Out:
# Plot(...)
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.UTF8String is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31

# %%
layers = []

for i in 1:nbasis(leg)
    for j in eachindex(xp,yp)
        yp[j] = derivative(leg, i, xp[j])
    end
    push!(layers, layer(x=xp, y=yp, Geom.line))
end

plot(layers...)
# Out:
# Plot(...)

# %%
layers = []

for i in 1:nbasis(leg)
    yp = zeros(xp)
    for j in eachindex(xp,yp)
        yp[j] = integral(leg, i, xp[j])
    end
    push!(layers, layer(x=xp, y=yp, Geom.line))
end

plot(layers...)
# Out:
# Plot(...)
