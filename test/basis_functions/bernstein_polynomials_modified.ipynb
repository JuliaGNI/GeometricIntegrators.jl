# %% [markdown]
# # Test Modified Bernstein Polynomials

# %%
using GeometricIntegrators
# Out:
# INFO: Recompiling stale cache file /Users/mkraus/.julia/lib/v0.6/GeometricIntegrators.ji for module GeometricIntegrators.

# %%
using Gadfly

# %% [markdown]
# Number of nodes:

# %%
s = 5
# Out:
# 5

# %% [markdown]
# Number of points to plot:

# %%
np = 31
# Out:
# 31

# %% [markdown]
# Obtain Gauss-Legendre nodes:

# %%
c = collect(linspace(0, 1, s))
# Out:
# 5-element Array{Float64,1}:
#  0.0
#  0.25
#  0.5
#  0.75
#  1.0

# %% [markdown]
# Define Bernstein polynomial:

# %%
ber = BernsteinBasisModified(c)
# Out:
# GeometricIntegrators.BasisFunctions.BernsteinBasisModified{Float64,4}([0.0, 0.25, 0.5, 0.75, 1.0])

# %% [markdown]
# Compute plot range:

# %%
xp = collect(linspace(0, 1, np));

# %% [markdown]
# Plot all basis polynomials:

# %%
layers = []

for i in 1:nbasis(ber)
    yp = zeros(np)
    for j in eachindex(xp,yp)
        yp[j] = evaluate(ber, i, xp[j])
    end
    push!(layers, layer(x=xp, y=yp, Geom.line))
end

plot(layers...)
# Out:
# Plot(...)

# %%
layers = []

for i in 1:nbasis(ber)
    yp = zeros(np)
    for j in eachindex(xp,yp)
        yp[j] = derivative(ber, i, xp[j])
    end
    push!(layers, layer(x=xp, y=yp, Geom.line))
end

plot(layers...)
# Out:
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
#   likely near /Users/mkraus/.julia/v0.6/IJulia/src/kernel.jl:31
# WARNING: Compat.ASCIIString is deprecated, use String instead.
# ...
